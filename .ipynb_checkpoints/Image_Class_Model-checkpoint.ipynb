# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'solid_dry_waste/train'
data_test_path = 'solid_dry_waste/test'
data_val_path = 'solid_dry_waste/validation'

# %%
img_width = 180
img_height =180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    r'C:\Users\James\OneDrive\Desktop\EcoMend\solid_dry_waste\train',  # Corrected the path to raw string
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 4757 files belonging to 3 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['disposable cups', 'paper', 'plastic bottle']

# %%
data_val_path = r'C:\Users\James\OneDrive\Desktop\EcoMend\solid_dry_waste\validation'  # Ensure this path is correct

data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    image_size=(img_height, img_width),
    batch_size=32,
    shuffle=False,
    validation_split=False
)
# Out:
# Found 1830 files belonging to 3 classes.

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    image_size=(img_height, img_width),
    batch_size=32,
    shuffle=False
)
# Out:
# Found 1830 files belonging to 3 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
                  
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 50
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 135s 839ms/step - accuracy: 0.5921 - loss: 1.7602 - val_accuracy: 0.6388 - val_loss: 0.8739
# Epoch 2/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 101s 569ms/step - accuracy: 0.7357 - loss: 0.6421 - val_accuracy: 0.6792 - val_loss: 0.7910
# Epoch 3/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 73s 491ms/step - accuracy: 0.7994 - loss: 0.4986 - val_accuracy: 0.6820 - val_loss: 0.7182
# Epoch 4/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 74s 499ms/step - accuracy: 0.8233 - loss: 0.4369 - val_accuracy: 0.7197 - val_loss: 0.8410
# Epoch 5/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 78s 526ms/step - accuracy: 0.8410 - loss: 0.3902 - val_accuracy: 0.7885 - val_loss: 0.6538
# Epoch 6/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 73s 489ms/step - accuracy: 0.8870 - loss: 0.2751 - val_accuracy: 0.7836 - val_loss: 0.8010
# Epoch 7/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 74s 496ms/step - accuracy: 0.9139 - loss: 0.2162 - val_accuracy: 0.7814 - val_loss: 0.8017
# Epoch 8/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 73s 491ms/step - accuracy: 0.9325 - loss: 0.1828 - val_accuracy: 0.8082 - val_loss: 0.7538
# Epoch 9/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 75s 500ms/step - accuracy: 0.9353 - loss: 0.1575 - val_accuracy: 0.7699 - val_loss: 0.9691
# Epoch 10/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 73s 490ms/step - accuracy: 0.9506 - loss: 0.1327 - val_accuracy: 0.7623 - val_loss: 1.1189
# Epoch 11/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 73s 486ms/step - accuracy: 0.9611 - loss: 0.1131 - val_accuracy: 0.7749 - val_loss: 1.2121
# Epoch 12/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━
50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 70s 468ms/step - accuracy: 0.9888 - loss: 0.0345 - val_accuracy: 0.7776 - val_loss: 2.0286
# Epoch 37/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 70s 471ms/step - accuracy: 0.9899 - loss: 0.0262 - val_accuracy: 0.7699 - val_loss: 2.3441
# Epoch 38/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 72s 479ms/step - accuracy: 0.9895 - loss: 0.0358 - val_accuracy: 0.7557 - val_loss: 2.1667
# Epoch 39/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 71s 475ms/step - accuracy: 0.9921 - loss: 0.0290 - val_accuracy: 0.8022 - val_loss: 2.1289
# Epoch 40/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 71s 474ms/step - accuracy: 0.9903 - loss: 0.0282 - val_accuracy: 0.7645 - val_loss: 2.2991
# Epoch 41/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 71s 472ms/step - accuracy: 0.9885 - loss: 0.0350 - val_accuracy: 0.7716 - val_loss: 2.1692
# Epoch 42/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 71s 476ms/step - accuracy: 0.9946 - loss: 0.0200 - val_accuracy: 0.8005 - val_loss: 2.1916
# Epoch 43/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 72s 480ms/step - accuracy: 0.9859 - loss: 0.0356 - val_accuracy: 0.7716 - val_loss: 2.1323
# Epoch 44/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 71s 473ms/step - accuracy: 0.9940 - loss: 0.0199 - val_accuracy: 0.7978 - val_loss: 2.3525
# Epoch 45/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 71s 475ms/step - accuracy: 0.9917 - loss: 0.0269 - val_accuracy: 0.7721 - val_loss: 2.5050
# Epoch 46/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 70s 467ms/step - accuracy: 0.9811 - loss: 0.0610 - val_accuracy: 0.7743 - val_loss: 2.0309
# Epoch 47/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 71s 477ms/step - accuracy: 0.9878 - loss: 0.0292 - val_accuracy: 0.7410 - val_loss: 2.7390
# Epoch 48/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 70s 471ms/step - accuracy: 0.9692 - loss: 0.0948 - val_accuracy: 0.7749 - val_loss: 2.0880
# Epoch 49/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - accuracy: 0.9954 - loss: 0.0163 - val_accuracy: 0.7945 - val_loss: 2.1447
# Epoch 50/50
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 70s 467ms/step - accuracy: 0.9976 - loss: 0.0058 - val_accuracy: 0.7945 - val_loss: 2.3390

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
# Full path to the image
image_path = r'C:\Users\James\OneDrive\Desktop\EcoMend\plasticBottle.jpg'

# Load the image
image = tf.keras.utils.load_img(image_path, target_size=(img_height, img_width))

# Convert the loaded image to an array
img_arr = tf.keras.utils.img_to_array(image)

# Create a batch dimension
img_bat = tf.expand_dims(img_arr, axis=0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is plastic bottle with accuracy of 100.00

# %%
model.save('C:/Users/James/OneDrive/Desktop/EcoMend/Image_classify.keras', save_format='keras')
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras
